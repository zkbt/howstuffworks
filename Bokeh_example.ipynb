# %%
#An easy way to make interactice plots using Bokeh's hovertool

#figure and show to create plot, output_file to save, and ColumnDataSource to prepare hover labels
from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.models import HoverTool  #for interaction

#For working in Jupyter Notebook: this displays outputs inline
from bokeh.io import output_notebook
output_notebook()

import numpy as np
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="23f9ed5b-5de4-4693-ba7d-406171114ae0">Loading BokehJS ...</span>
#     </div>

# %%
#SETTING UP DATA
y_values = np.asarray([5, 2, 7, 4, 9])
x_values = np.asarray([11, 4, 7, 8, 2])
labels = np.asarray(['Ginger', 'Max', 'Tigger', 'Bagel', 'Felix']) #labels for each data point

# %%
#PLOTTING
output_file('example.html')  #optional, saves webpage of plot
source0 = ColumnDataSource(data=dict(x=x_values, y=y_values, desc=labels))          #x, y, and label for each data point

#Here we add the hovertool and choose the 'type' of label - ie. names
hover = HoverTool(tooltips=[("Name", "@desc")])

#Now we set up a figure with labels:
p = figure(title="Very Real Data", x_axis_label='Weight', y_axis_label='Age', tools=[hover])
#(some other useful argument examples for figure(): plot_width=500, plot_height=400, y_range=(0, 15), y_axis_type="log")

#...then create and set characteristics of points
p.circle('x', 'y', size=10, source=source0)

show(p)  #display plot! A webpage should automatically open up
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="22984fea-fe64-4527-9285-ab72e1772320"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("22984fea-fe64-4527-9285-ab72e1772320").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("22984fea-fe64-4527-9285-ab72e1772320");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '22984fea-fe64-4527-9285-ab72e1772320' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"366afb23-408a-4c31-9026-5b03915279b6":{"roots":{"references":[{"attributes":{"axis_label":"Weight","formatter":{"id":"3120f6ae-1ef0-439a-9728-1a92ad03fe76","type":"BasicTickFormatter"},"plot":{"id":"e2a0da43-515c-4281-93d2-0492a69e5fca","subtype":"Figure","type":"Plot"},"ticker":{"id":"77d76ca4-cd4c-4b40-8a96-6312c38e7171","type":"BasicTicker"}},"id":"ad4c1db6-cf1b-47d6-89b3-86821646c110","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2439010a-d5ff-420b-8f0e-6c26282a0280","type":"HoverTool"}]},"id":"b0ae3e50-55b4-4a5f-a7f1-eec4238a1fe9","type":"Toolbar"},{"attributes":{"below":[{"id":"ad4c1db6-cf1b-47d6-89b3-86821646c110","type":"LinearAxis"}],"left":[{"id":"4063b1a1-e5c3-4cb8-80b2-c699726d5b0d","type":"LinearAxis"}],"renderers":[{"id":"ad4c1db6-cf1b-47d6-89b3-86821646c110","type":"LinearAxis"},{"id":"427193d5-1002-4401-9cf0-0a57512e0533","type":"Grid"},{"id":"4063b1a1-e5c3-4cb8-80b2-c699726d5b0d","type":"LinearAxis"},{"id":"35ccee23-4e1a-4da4-acbc-1b33b2bcb323","type":"Grid"},{"id":"555084fd-3ddc-435a-a15d-7ac3c266e7b2","type":"GlyphRenderer"}],"title":{"id":"6a8c2ba1-c641-48f5-b45b-5642c05b9e7d","type":"Title"},"tool_events":{"id":"7fcda9aa-3163-4395-918b-81e2c200d601","type":"ToolEvents"},"toolbar":{"id":"b0ae3e50-55b4-4a5f-a7f1-eec4238a1fe9","type":"Toolbar"},"x_range":{"id":"109ecfe1-7dd8-408b-93b9-38051e16fc58","type":"DataRange1d"},"y_range":{"id":"70270077-787a-46a9-bf4f-f8754d7de7e9","type":"DataRange1d"}},"id":"e2a0da43-515c-4281-93d2-0492a69e5fca","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7fcda9aa-3163-4395-918b-81e2c200d601","type":"ToolEvents"},{"attributes":{"callback":null},"id":"109ecfe1-7dd8-408b-93b9-38051e16fc58","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"e2a0da43-515c-4281-93d2-0492a69e5fca","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@desc"]]},"id":"2439010a-d5ff-420b-8f0e-6c26282a0280","type":"HoverTool"},{"attributes":{},"id":"3120f6ae-1ef0-439a-9728-1a92ad03fe76","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"e2a0da43-515c-4281-93d2-0492a69e5fca","subtype":"Figure","type":"Plot"},"ticker":{"id":"484fe74a-6f10-4e93-a403-bd20d672d4c5","type":"BasicTicker"}},"id":"35ccee23-4e1a-4da4-acbc-1b33b2bcb323","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a4705520-5dbc-44d3-ae0f-baa7fe5c52d5","type":"Circle"},{"attributes":{},"id":"77d76ca4-cd4c-4b40-8a96-6312c38e7171","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x","desc"],"data":{"desc":["Ginger","Max","Tigger","Bagel","Felix"],"x":{"__ndarray__":"CwAAAAQAAAAHAAAACAAAAAIAAAA=","dtype":"int32","shape":[5]},"y":{"__ndarray__":"BQAAAAIAAAAHAAAABAAAAAkAAAA=","dtype":"int32","shape":[5]}}},"id":"32d98384-2681-4177-a743-f821f4a5c23c","type":"ColumnDataSource"},{"attributes":{},"id":"4d01e8bd-a036-41fb-9f47-0cebfdb1533d","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Very Real Data"},"id":"6a8c2ba1-c641-48f5-b45b-5642c05b9e7d","type":"Title"},{"attributes":{},"id":"484fe74a-6f10-4e93-a403-bd20d672d4c5","type":"BasicTicker"},{"attributes":{"axis_label":"Age","formatter":{"id":"4d01e8bd-a036-41fb-9f47-0cebfdb1533d","type":"BasicTickFormatter"},"plot":{"id":"e2a0da43-515c-4281-93d2-0492a69e5fca","subtype":"Figure","type":"Plot"},"ticker":{"id":"484fe74a-6f10-4e93-a403-bd20d672d4c5","type":"BasicTicker"}},"id":"4063b1a1-e5c3-4cb8-80b2-c699726d5b0d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"32d98384-2681-4177-a743-f821f4a5c23c","type":"ColumnDataSource"},"glyph":{"id":"a4705520-5dbc-44d3-ae0f-baa7fe5c52d5","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"23f16bfc-5349-4414-a72a-80c798a45129","type":"Circle"},"selection_glyph":null},"id":"555084fd-3ddc-435a-a15d-7ac3c266e7b2","type":"GlyphRenderer"},{"a ...

# %%
#...but what if you want more than one data set?
y_values1 = np.asarray([8, 5, 7, 9, 11])
x_values1 = np.asarray([10, 2, 6, 4, 8])
labels1 = np.asarray(['Kiler', '2Pac', 'Ripper', 'Spike', 'Thrash']) #labels for each data point

# %%
#all you have to do is add another source
output_file('example.html')
source0 = ColumnDataSource(data=dict(x=x_values, y=y_values, desc=labels))          #x, y, and label for each data point
source1 = ColumnDataSource(data=dict(x=x_values1, y=y_values1, desc=labels1))

#Here we add the hovertool and choose the 'type' of label - ie. names
hover = HoverTool(tooltips=[("Name", "@desc")])

#Now we set up a figure with labels:
p = figure(title="Very Real Data", x_axis_label='Weight', y_axis_label='Age', tools=[hover])

#...then create and set characteristics of points for each dataset and a legend label
p.circle('x', 'y', size=10, source=source0, color='blue', legend='Blue')
p.circle('x', 'y', size=10, source=source1, color='red', legend='Red')

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'example.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="522c4ba3-5d0c-4dda-aa04-3b69c922a161"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("522c4ba3-5d0c-4dda-aa04-3b69c922a161").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("522c4ba3-5d0c-4dda-aa04-3b69c922a161");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '522c4ba3-5d0c-4dda-aa04-3b69c922a161' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d04cb64e-367c-4322-8aea-27019de5ee01":{"roots":{"references":[{"attributes":{"below":[{"id":"eb2a3648-a646-4d75-9331-91fb2461be1c","type":"LinearAxis"}],"left":[{"id":"772562cc-9f0b-407c-a0db-0ed2eb574044","type":"LinearAxis"}],"renderers":[{"id":"eb2a3648-a646-4d75-9331-91fb2461be1c","type":"LinearAxis"},{"id":"29ae7aa6-0e42-4cf8-96bc-9c32245a0849","type":"Grid"},{"id":"772562cc-9f0b-407c-a0db-0ed2eb574044","type":"LinearAxis"},{"id":"730baacf-cfd2-47e4-8c5f-2b88f53f4090","type":"Grid"},{"id":"9dca8b38-591b-419f-9e1d-22e43a9f4e0e","type":"Legend"},{"id":"89856849-3b29-4ccc-8584-958080b0ced6","type":"GlyphRenderer"},{"id":"389e9d57-47ce-4110-ab83-07cfb75990b8","type":"GlyphRenderer"}],"title":{"id":"e033dc3b-974a-44d8-9615-db7bb834a409","type":"Title"},"tool_events":{"id":"e83e6a2c-8291-4e60-9f06-4261b57b31b6","type":"ToolEvents"},"toolbar":{"id":"2c627a55-3cad-41df-a88a-8172389d47fb","type":"Toolbar"},"x_range":{"id":"56533316-ddc2-4f24-8cec-73f7ec90b325","type":"DataRange1d"},"y_range":{"id":"d6fcfc3d-9980-43f6-9a37-b526a29ce991","type":"DataRange1d"}},"id":"d40de694-29cf-4ff6-8a14-6661d4ad206f","subtype":"Figure","type":"Plot"},{"attributes":{"items":[{"id":"3d953722-5219-4c3f-a757-d398f367e204","type":"LegendItem"},{"id":"ab572214-274a-4da5-acad-e6b260270ce8","type":"LegendItem"}],"plot":{"id":"d40de694-29cf-4ff6-8a14-6661d4ad206f","subtype":"Figure","type":"Plot"}},"id":"9dca8b38-591b-419f-9e1d-22e43a9f4e0e","type":"Legend"},{"attributes":{"callback":null,"plot":{"id":"d40de694-29cf-4ff6-8a14-6661d4ad206f","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@desc"]]},"id":"eb031099-ded7-43ce-8264-2e13b7639391","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"bbd7b6a3-a0f1-4359-8fcc-0d0143171558","type":"Circle"},{"attributes":{},"id":"e83e6a2c-8291-4e60-9f06-4261b57b31b6","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"b2f45fa6-65eb-4f95-8809-7ed8ddadea92","type":"Circle"},{"attributes":{},"id":"04cb84dc-d72a-4bc9-9a5a-d8eaf5096ab7","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"51275233-7ea5-4238-b7d5-cfc6a8ff5caa","type":"Circle"},{"attributes":{"callback":null},"id":"d6fcfc3d-9980-43f6-9a37-b526a29ce991","type":"DataRange1d"},{"attributes":{"data_source":{"id":"c4a2a80e-b6a2-4e94-8f28-d1e02459d4b9","type":"ColumnDataSource"},"glyph":{"id":"b2f45fa6-65eb-4f95-8809-7ed8ddadea92","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"2880aab2-2101-4163-95ea-17f1030ad33f","type":"Circle"},"selection_glyph":null},"id":"389e9d57-47ce-4110-ab83-07cfb75990b8","type":"GlyphRenderer"},{"attributes":{},"id":"0272fe7c-1b96-4f09-92a3-bbf5b0b2a8a5","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x","desc"],"data":{"desc":["Ginger","Max","Tigger","Bagel","Felix"],"x":{"__ndarray__":"CwAAAAQAAAAHAAAACAAAAAIAAAA=","dtype":"int32","shape":[5]},"y":{"__ndarray__":"BQAAAAIAAAAHAAAABAAAAAkAAAA=","dtype":"int32","shape":[5]}}},"id":"c96a7022-8c57-480e-8202-53a1471e5eae","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"d40de694-29cf-4ff6-8a14-6661d4ad206f","subtype":"Figure","type":"Plot"},"ticker":{"id":"521e8744-68da-4e50-a487-f4196c3afa3a","type":"BasicTicker"}},"id":"29ae7aa6-0e42-4cf8-96bc-9c32245a0849","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"2880aab2-2101-4163-95ea-17f1030ad33f","type":"Circle"},{"attributes":{},"id":"8c3afffc-1672-43e ...

# %%
#It's also simple to include the values of each point in its label by just adding arguments to Hover()

#Plotting
output_file('example.html')
source0 = ColumnDataSource(data=dict(x=x_values, y=y_values, desc=labels))          #x, y, and label for each data point

#Adding additional labels
hover = HoverTool(tooltips=[("Name", "@desc"), ('Weight', '$x lbs'), ('Age', '$y years')])

#Now we set up a figure with labels:
p = figure(title="Very Real Data", x_axis_label='Weight', y_axis_label='Age', tools=[hover])

#...then create and set characteristics of points
p.circle('x', 'y', size=10, source=source0)

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'example.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="58c2abbf-0abc-4464-ab92-eed34b3192f8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("58c2abbf-0abc-4464-ab92-eed34b3192f8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("58c2abbf-0abc-4464-ab92-eed34b3192f8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '58c2abbf-0abc-4464-ab92-eed34b3192f8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"653c163c-582c-45a5-aac9-b485548c06ba":{"roots":{"references":[{"attributes":{"below":[{"id":"28a90d10-e7fa-4a25-adc6-78c3693245ae","type":"LinearAxis"}],"left":[{"id":"3e1fb1a3-d46a-4370-a23e-0742b745e5f0","type":"LinearAxis"}],"renderers":[{"id":"28a90d10-e7fa-4a25-adc6-78c3693245ae","type":"LinearAxis"},{"id":"b9e765c2-ca1a-4385-af5d-32f2c4131ffa","type":"Grid"},{"id":"3e1fb1a3-d46a-4370-a23e-0742b745e5f0","type":"LinearAxis"},{"id":"7ba781b1-11e4-4083-b1ec-1d4bb734cfbe","type":"Grid"},{"id":"b3c21817-9ff0-434c-a3a1-5f4ed62c78d5","type":"GlyphRenderer"}],"title":{"id":"b09e78f7-8e1a-4260-b171-e8fd9cec3427","type":"Title"},"tool_events":{"id":"e5a578bd-df98-4f80-b1e6-85a31b2b01e8","type":"ToolEvents"},"toolbar":{"id":"fbe7314f-356c-4cbe-945d-2d92eba54f0f","type":"Toolbar"},"x_range":{"id":"40280106-4550-4480-a513-c51fa2476703","type":"DataRange1d"},"y_range":{"id":"ccd6e54c-acf7-4bce-894c-e2f44f958349","type":"DataRange1d"}},"id":"63b610c8-2477-4872-a95a-de62ce95db6c","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"fc11a2d6-770d-4335-92a6-7edc146476b4","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d0b9387-65ce-4488-8cc8-95148126f726","type":"Circle"},{"attributes":{"callback":null},"id":"40280106-4550-4480-a513-c51fa2476703","type":"DataRange1d"},{"attributes":{},"id":"3b8dd81e-e61a-4648-bbec-fb6b78f5c2c1","type":"BasicTicker"},{"attributes":{"plot":{"id":"63b610c8-2477-4872-a95a-de62ce95db6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b8dd81e-e61a-4648-bbec-fb6b78f5c2c1","type":"BasicTicker"}},"id":"b9e765c2-ca1a-4385-af5d-32f2c4131ffa","type":"Grid"},{"attributes":{"callback":null},"id":"ccd6e54c-acf7-4bce-894c-e2f44f958349","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"63b610c8-2477-4872-a95a-de62ce95db6c","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@desc"],["Weight","$x lbs"],["Age","$y years"]]},"id":"2e61be88-7ee3-4e5e-bebd-b6ba8cb48a35","type":"HoverTool"},{"attributes":{},"id":"207b8df1-a0c1-4dab-bdd1-0ef4ad9ed387","type":"BasicTickFormatter"},{"attributes":{},"id":"a542b662-1a15-4544-a082-ac12de43f94b","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"878afb2e-4e6d-4e7d-85d1-4b7908be8216","type":"Circle"},{"attributes":{"axis_label":"Age","formatter":{"id":"fc11a2d6-770d-4335-92a6-7edc146476b4","type":"BasicTickFormatter"},"plot":{"id":"63b610c8-2477-4872-a95a-de62ce95db6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"a542b662-1a15-4544-a082-ac12de43f94b","type":"BasicTicker"}},"id":"3e1fb1a3-d46a-4370-a23e-0742b745e5f0","type":"LinearAxis"},{"attributes":{"axis_label":"Weight","formatter":{"id":"207b8df1-a0c1-4dab-bdd1-0ef4ad9ed387","type":"BasicTickFormatter"},"plot":{"id":"63b610c8-2477-4872-a95a-de62ce95db6c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b8dd81e-e61a-4648-bbec-fb6b78f5c2c1","type":"BasicTicker"}},"id":"28a90d10-e7fa-4a25-adc6-78c3693245ae","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Very Real Data"},"id":"b09e78f7-8e1a-4260-b171-e8fd9cec3427","type":"Title"},{"attributes":{},"id":"e5a578bd-df98-4f80-b1e6-85a31b2b01e8","type":"ToolEvents"},{"attributes":{"data_source":{"id":"5b14e666-8c8b-44a2-a0ab-e8cfdc0aff85","type":"ColumnDataSource"},"glyph":{"id":"8d0b9387-65ce-4488-8cc8-95148126f726","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"878afb2e-4e6d-4e7d-85d1-4b7908be8216","type":"Circle"},"selection_glyph":null},"id":"b3c21817-9ff0-434c-a3a1-5f4ed62c78d5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x","desc"],"data":{"desc":["Ginger","Max","Tigger","Bagel","Felix"],"x":{"__ndarray__":"CwAAAAQAAAAHAAAACAAAAAIAAAA=","dtype": ...
