# %%
#An easy way to make interactice plots using Bokeh's hovertool

#figure and show to create plot, output_file to save, and ColumnDataSource to prepare hover labels
from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.models import HoverTool  #for interaction

#For working in Jupyter Notebook: this displays outputs inline
from bokeh.io import output_notebook
output_notebook()

import numpy as np
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb5da4f3-efe9-4741-be2f-b4852ad8270e">Loading BokehJS ...</span>
#     </div>

# %%
#SETTING UP DATA
y_values = np.asarray([5, 2, 7, 4, 9])
x_values = np.asarray([11, 4, 7, 8, 2])
labels = np.asarray(['Ginger', 'Max', 'Tigger', 'Bagel', 'Felix']) #labels for each data point

# %%
#PLOTTING
output_file('example.html')  #optional, saves webpage of plot
source0 = ColumnDataSource(data=dict(x=x_values, y=y_values, desc=labels))          #x, y, and label for each data point

#Here we add the hovertool and choose the 'type' of label - ie. names
hover = HoverTool(tooltips=[("Name", "@desc")])

#Now we set up a figure with labels:
p = figure(title="Very Real Data", x_axis_label='Weight', y_axis_label='Age', tools=[hover])
#(some other useful argument examples for figure(): plot_width=500, plot_height=400, y_range=(0, 15), y_axis_type="log")

#...then create and set characteristics of points
p.circle('x', 'y', size=10, source=source0)

show(p)  #display plot! A webpage should automatically open up
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1c13a2f4-1ae8-4fed-b238-93beb078f051"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1c13a2f4-1ae8-4fed-b238-93beb078f051");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c13a2f4-1ae8-4fed-b238-93beb078f051");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c13a2f4-1ae8-4fed-b238-93beb078f051' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d04d0cdb-deb4-4190-8e1e-86eed083b051":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"102817d6-c017-4905-9e89-99e4e4108072","type":"HoverTool"}]},"id":"6716916f-0644-41fa-89ef-570748ee8890","type":"Toolbar"},{"attributes":{"data_source":{"id":"251082e9-bda4-4c34-bb6c-b7373f16de77","type":"ColumnDataSource"},"glyph":{"id":"607b6e89-343d-4bc0-b307-f9b606311e3b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7417c069-ca1b-4c4a-8ef9-d453da0193d6","type":"Circle"},"selection_glyph":null},"id":"32cdad74-15ce-4a51-972c-4c3d3ac4754f","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Very Real Data"},"id":"888328dd-3404-4b10-bfe1-d1a20f82fcc7","type":"Title"},{"attributes":{},"id":"4f0a9a99-c2ea-433f-a24e-abb025780296","type":"BasicTickFormatter"},{"attributes":{},"id":"455f359f-4c22-4ef2-ba00-d0b773cf81ef","type":"LinearScale"},{"attributes":{"callback":null,"plot":{"id":"aaf178f4-136a-4ee3-9c5d-fcd0145d9b67","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@desc"]]},"id":"102817d6-c017-4905-9e89-99e4e4108072","type":"HoverTool"},{"attributes":{},"id":"03022d32-502e-4778-b292-954e5d5fd575","type":"LinearScale"},{"attributes":{},"id":"7b9f1126-2b4e-4be7-8d40-0fd842161c18","type":"BasicTickFormatter"},{"attributes":{},"id":"bcd46057-b91e-4622-ad38-c95167a8d548","type":"BasicTicker"},{"attributes":{"callback":null},"id":"a71555c1-3c0e-42e0-b397-f5649c375aab","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"7417c069-ca1b-4c4a-8ef9-d453da0193d6","type":"Circle"},{"attributes":{"axis_label":"Weight","formatter":{"id":"4f0a9a99-c2ea-433f-a24e-abb025780296","type":"BasicTickFormatter"},"plot":{"id":"aaf178f4-136a-4ee3-9c5d-fcd0145d9b67","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcd46057-b91e-4622-ad38-c95167a8d548","type":"BasicTicker"}},"id":"8f0ca152-0138-4eed-83b7-7b42d64f9d0f","type":"LinearAxis"},{"attributes":{"plot":{"id":"aaf178f4-136a-4ee3-9c5d-fcd0145d9b67","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcd46057-b91e-4622-ad38-c95167a8d548","type":"BasicTicker"}},"id":"660a88b5-c278-4d99-b078-9a1cc8a30aa6","type":"Grid"},{"attributes":{"axis_label":"Age","formatter":{"id":"7b9f1126-2b4e-4be7-8d40-0fd842161c18","type":"BasicTickFormatter"},"plot":{"id":"aaf178f4-136a-4ee3-9c5d-fcd0145d9b67","subtype":"Figure","type":"Plot"},"ticker":{"id":"84d16037-ccb9-46c2-a865-cf6ffd69b700","type":"BasicTicker"}},"id":"8b1ecf98-7180-4175-b566-1ba805b5cb22","type":"LinearAxis"},{"attributes":{},"id":"84d16037-ccb9-46c2-a865-cf6ffd69b700","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"aaf178f4-136a-4ee3-9c5d-fcd0145d9b67","subtype":"Figure","type":"Plot"},"ticker":{"id":"84d16037-ccb9-46c2-a865-cf6ffd69b700","type":"BasicTicker"}},"id":"49a979e1-54ba-496a-9348-14d44032516c","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"607b6e89-343d-4bc0-b307-f9b606311e3b","type":"Circle"},{"attributes":{"callback":null},"id":"4d349481-9405-449e-aa91-2ba9f94110b7","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y","desc"],"data":{"desc":["Ginger","Max","Tigger","Bagel","Felix"],"x":[11,4,7,8,2],"y":[5,2,7,4,9]}},"id":"251082e9-bda4-4c34-bb6c-b7373f16de77","type":"ColumnDataSource"},{"attributes":{},"id":"29aed722-532c-40ba-a616-cbe57c4c5c74","type":"ToolEvents"},{"attributes":{"below":[{"id":"8f0ca152-0138-4eed-83b7-7b42d64f9d0f","type":"LinearAxis"}],"left":[{"id":"8b1ecf98-7180-4175-b566-1ba805b5cb22","type":"LinearAxis"}],"renderers":[{"id":"8f0ca152-0138-4eed-83b7-7b42d64f9d0f","type":"LinearAxis"},{"id":"660a88b5-c278-4d99 ...

# %%
#...but what if you want more than one data set?
y_values1 = np.asarray([8, 5, 7, 9, 11])
x_values1 = np.asarray([10, 2, 6, 4, 8])
labels1 = np.asarray(['Kiler', '2Pac', 'Ripper', 'Spike', 'Thrash']) #labels for each data point

# %%
#all you have to do is add another source
output_file('example.html')
source0 = ColumnDataSource(data=dict(x=x_values, y=y_values, desc=labels))          #x, y, and label for each data point
source1 = ColumnDataSource(data=dict(x=x_values1, y=y_values1, desc=labels1))

#Here we add the hovertool and choose the 'type' of label - ie. names
hover = HoverTool(tooltips=[("Name", "@desc")])

#Now we set up a figure with labels:
p = figure(title="Very Real Data", x_axis_label='Weight', y_axis_label='Age', tools=[hover])

#...then create and set characteristics of points for each dataset and a legend label
p.circle('x', 'y', size=10, source=source0, color='blue', legend='Blue')
p.circle('x', 'y', size=10, source=source1, color='red', legend='Red')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d88729b6-11fe-42fc-80f7-8fb9cd4914ca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d88729b6-11fe-42fc-80f7-8fb9cd4914ca");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
olbar":{"id":"8eba08a1-36cd-479f-b604-5d9dd41b4d7c","type":"Toolbar"},"x_range":{"id":"bad60c93-fa27-4e21-b33f-a93e334e6088","type":"DataRange1d"},"x_scale":{"id":"c668ece4-4bbe-46c9-8b73-471d7cdf7ea5","type":"LinearScale"},"y_range":{"id":"acd7888d-7186-425c-85f2-34ad779c266b","type":"DataRange1d"},"y_scale":{"id":"d8ca5a4e-8aa4-4b8d-bee0-9e4f08f37307","type":"LinearScale"}},"id":"5a512a00-9656-4169-a36c-0a8a04c629d6","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5a512a00-9656-4169-a36c-0a8a04c629d6","subtype":"Figure","type":"Plot"},"ticker":{"id":"57aecd82-6b46-4a32-a5d4-b6cfb8fc4bc0","type":"BasicTicker"}},"id":"76034393-e035-431e-922f-d906f03cb155","type":"Grid"},{"attributes":{},"id":"13c7a890-56cf-4aa4-9604-7aac33ccf89b","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y","desc"],"data":{"desc":["Ginger","Max","Tigger","Bagel","Felix"],"x":[11,4,7,8,2],"y":[5,2,7,4,9]}},"id":"35916311-e8ca-40f2-bc02-31cb1bd6cdfc","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"acd7888d-7186-425c-85f2-34ad779c266b","type":"DataRange1d"},{"attributes":{},"id":"d8ca5a4e-8aa4-4b8d-bee0-9e4f08f37307","type":"LinearScale"},{"attributes":{"plot":null,"text":"Very Real Data" ...

# %%
#It's also simple to include the values of each point in its label by just adding arguments to Hover()

#Plotting
output_file('example.html')
source0 = ColumnDataSource(data=dict(x=x_values, y=y_values, desc=labels))          #x, y, and label for each data point

#Adding additional labels
hover = HoverTool(tooltips=[("Name", "@desc"), ('Weight', '$x lbs'), ('Age', '$y years')])

#Now we set up a figure with labels:
p = figure(title="Very Real Data", x_axis_label='Weight', y_axis_label='Age', tools=[hover])

#...then create and set characteristics of points
p.circle('x', 'y', size=10, source=source0)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6986c6df-6e25-4215-8a0b-673183bd172c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6986c6df-6e25-4215-8a0b-673183bd172c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6986c6df-6e25-4215-8a0b-673183bd172c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6986c6df-6e25-4215-8a0b-673183bd172c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"44ca4bf7-29d8-445b-a34c-a74e46036097":{"roots":{"references":[{"attributes":{"callback":null},"id":"d80a464a-2ff0-4dcf-8aa6-16f13b3d5bcb","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"53b7250c-89cb-43dc-abb0-998e009c801a","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf699da8-5370-4885-a9df-d603b5e30264","type":"BasicTicker"}},"id":"1dec396d-aaf0-4820-84de-277a031c151b","type":"Grid"},{"attributes":{},"id":"1753c7de-3102-44ba-8200-b059cf361660","type":"ToolEvents"},{"attributes":{},"id":"4eface5f-9f5f-4cdd-a9e1-856cec7f5234","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"53b7250c-89cb-43dc-abb0-998e009c801a","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@desc"],["Weight","$x lbs"],["Age","$y years"]]},"id":"c0a1bdf0-0e93-49ec-879d-c11e90252d65","type":"HoverTool"},{"attributes":{"below":[{"id":"3488cc22-cdc0-4489-a4d7-6211d8b33653","type":"LinearAxis"}],"left":[{"id":"abf8beac-e1db-48d9-a3b3-aa623f3a267c","type":"LinearAxis"}],"renderers":[{"id":"3488cc22-cdc0-4489-a4d7-6211d8b33653","type":"LinearAxis"},{"id":"e